# %%
import pandas as pd
cinema_df= pd.read_csv("C:\\Users\\DIGITALDREAM CYBER\\Downloads\\cinema.csv")
cinema_df
# Out:
#     Unnamed: 0                                         Title  title_year  \
# 0            0                                    La La Land        2016
# 1            1                                      Zootopia        2016
# 2            2                                          Lion        2016
# 3            3                                       Arrival        2016
# 4            4                         Manchester by the Sea        2016
# ..         ...                                           ...         ...
# 95          95                                      Whiplash        2014
# 96          96                               Before Midnight        2013
# 97          97    Star Wars: Episode VII - The Force Awakens        2015
# 98          98  Harry Potter and the Deathly Hallows: Part I        2010
# 99          99                       Tucker and Dale vs Evil        2010
#
#        budget      Gross              actor_1_name        actor_2_name  \
# ...

# %%
cinema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              100 non-null    int64
#  1   Title                   100 non-null    object
#  2   title_year              100 non-null    int64
#  3   budget                  100 non-null    int64
#  4   Gross                   100 non-null    int64
#  5   actor_1_name            100 non-null    object
#  6   actor_2_name            100 non-null    object
#  7   actor_3_name            100 non-null    object
#  8   actor_1_facebook_likes  100 non-null    int64
#  9   actor_2_facebook_likes  99 non-null     float64
#  10  actor_3_facebook_likes  98 non-null     float64
#  11  IMDb_rating             100 non-null    float64
#  12  genre_1                 100 non-null    object
#  13  genre_2                 97 non-null     object
# ...

# %%
budget_column =cinema_df["budget"]
budget_column
# Out:
# 0      30000000
# 1     150000000
# 2      12000000
# 3      47000000
# 4       9000000
#         ...
# 95      3300000
# 96      3000000
# 97    245000000
# 98    150000000
# 99      5000000
# Name: budget, Length: 100, dtype: int64

# %%
new_budget_column = budget_column/1000000
new_budget_column
# Out:
# 0      30.0
# 1     150.0
# 2      12.0
# 3      47.0
# 4       9.0
#       ...
# 95      3.3
# 96      3.0
# 97    245.0
# 98    150.0
# 99      5.0
# Name: budget, Length: 100, dtype: float64

# %%
Gross_column =cinema_df["Gross"]
Gross_column
# Out:
# 0     151101803
# 1     341268248
# 2      51738905
# 3     100546139
# 4      47695371
#         ...
# 95     13092000
# 96      8114507
# 97    936662225
# 98    296347721
# 99       223838
# Name: Gross, Length: 100, dtype: int64

# %%
cinema_df.rename(columns ={'budget' : 'budget(million $)',
                     'Gross':'Gross(million $)'},inplace = True)

# %%
cinema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              100 non-null    int64
#  1   Title                   100 non-null    object
#  2   title_year              100 non-null    int64
#  3   budget(million $)       100 non-null    int64
#  4   Gross(million $)        100 non-null    int64
#  5   actor_1_name            100 non-null    object
#  6   actor_2_name            100 non-null    object
#  7   actor_3_name            100 non-null    object
#  8   actor_1_facebook_likes  100 non-null    int64
#  9   actor_2_facebook_likes  99 non-null     float64
#  10  actor_3_facebook_likes  98 non-null     float64
#  11  IMDb_rating             100 non-null    float64
#  12  genre_1                 100 non-null    object
#  13  genre_2                 97 non-null     object
# ...

# %%
cinema_df["profit"] = cinema_df['Gross(million $)'] - cinema_df['budget(million $)']
cinema_df
# Out:
#     Unnamed: 0                                         Title  title_year  \
# 0            0                                    La La Land        2016
# 1            1                                      Zootopia        2016
# 2            2                                          Lion        2016
# 3            3                                       Arrival        2016
# 4            4                         Manchester by the Sea        2016
# ..         ...                                           ...         ...
# 95          95                                      Whiplash        2014
# 96          96                               Before Midnight        2013
# 97          97    Star Wars: Episode VII - The Force Awakens        2015
# 98          98  Harry Potter and the Deathly Hallows: Part I        2010
# 99          99                       Tucker and Dale vs Evil        2010
#
#     budget(million $)  Gross(million $)              actor_1_name  \
# ...

# %%
cinema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              100 non-null    int64
#  1   Title                   100 non-null    object
#  2   title_year              100 non-null    int64
#  3   budget(million $)       100 non-null    int64
#  4   Gross(million $)        100 non-null    int64
#  5   actor_1_name            100 non-null    object
#  6   actor_2_name            100 non-null    object
#  7   actor_3_name            100 non-null    object
#  8   actor_1_facebook_likes  100 non-null    int64
#  9   actor_2_facebook_likes  99 non-null     float64
#  10  actor_3_facebook_likes  98 non-null     float64
#  11  IMDb_rating             100 non-null    float64
#  12  genre_1                 100 non-null    object
#  13  genre_2                 97 non-null     object
# ...

# %%
cinema_df.set_index("profit" ,inplace =True)

# %%
cinema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 121101803 to -4776162
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              100 non-null    int64
#  1   Title                   100 non-null    object
#  2   title_year              100 non-null    int64
#  3   budget(million $)       100 non-null    int64
#  4   Gross(million $)        100 non-null    int64
#  5   actor_1_name            100 non-null    object
#  6   actor_2_name            100 non-null    object
#  7   actor_3_name            100 non-null    object
#  8   actor_1_facebook_likes  100 non-null    int64
#  9   actor_2_facebook_likes  99 non-null     float64
#  10  actor_3_facebook_likes  98 non-null     float64
#  11  IMDb_rating             100 non-null    float64
#  12  genre_1                 100 non-null    object
#  13  genre_2                 97 non-null     object
# ...

# %%
cinema_df.head(10)
# Out:
#             Unnamed: 0                       Title  title_year  \
# profit
#  121101803           0                  La La Land        2016
#  191268248           1                    Zootopia        2016
#  39738905            2                        Lion        2016
#  53546139            3                     Arrival        2016
#  38695371            4       Manchester by the Sea        2016
#  15007844            5          Hell or High Water        2016
#  67641920            6              Doctor Strange        2016
# -59192738            7                     Tangled        2010
#  198130642           8       The Dark Knight Rises        2012
#  157197282           9  Captain America: Civil War        2016
#
#             budget(million $)  Gross(million $)          actor_1_name  \
# profit
#  121101803           30000000         151101803          Ryan Gosling
#  191268248          150000000         341268248      Ginnifer Goodwin
# ...

# %%
cinema_sorted=cinema_df.sort_values(by ="profit",ascending = False)
cinema_sorted
# Out:
#             Unnamed: 0                                       Title  \
# profit
#  691662225          97  Star Wars: Episode VII - The Force Awakens
#  403279547          11                                The Avengers
#  305024263          47                                    Deadpool
#  294645577          32             The Hunger Games: Catching Fire
#  214984497          12                                 Toy Story 3
# ...                ...                                         ...
# -28505730           46                 Scott Pilgrim vs. the World
# -59192738            7                                     Tangled
# -77810499           17                            Edge of Tomorrow
# -79860848           39                           The Little Prince
# -96179906           22                                        Hugo
#
#             title_year  budget(million $)  Gross(million $)  \
# profit
#  691662225        2015          245000000         936662225
# ...

# %%
Neg_profit =cinema_sorted[cinema_sorted.index<0]
Neg_profit
# Out:
#            Unnamed: 0                        Title  title_year  \
# profit
# -4776162           99      Tucker and Dale vs Evil        2010
# -8674623           89                        Amour        2012
# -11096291          56                         Rush        2013
# -11348338          66                      Warrior        2011
# -12247786          82                      Flipped        2010
# -13594629          28           X-Men: First Class        2011
# -28505730          46  Scott Pilgrim vs. the World        2010
# -59192738           7                      Tangled        2010
# -77810499          17             Edge of Tomorrow        2014
# -79860848          39            The Little Prince        2015
# -96179906          22                         Hugo        2011
#
#            budget(million $)  Gross(million $)         actor_1_name  \
# profit
# -4776162             5000000            223838       Katrina Bowden
# ...

# %%
genre_types = cinema_sorted.groupby("genre_1")
plt.figure(figsize = (10,7)),
plt.bar(cinema_sorted["genre_1"].unique(),cinema_sorted["genre_1"].value_counts(),color ="blue"),
plt.ylabel("genre_count"),
plt.xlabel("genre_types"),
plt.show()
